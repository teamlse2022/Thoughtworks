# %% [markdown]
# # CO2_LSE Employer Project - ThoughtWorks

# %% [markdown]
# # Data Analysis for London Data (Central London, Inner London, Biking Sites)

# %%
# Importing Numpy, Pandas, Seaborn and Matplotlib libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Data Exploration (EDA) of Central & Inner London Datasets 'as is'

# %%
# Central London Dataset
# Loading csv into a dataframe
cent_lon = pd.read_csv("Central London.csv")

# Displaying first 5 Rows of the dataset
cent_lon.head()
# Out:
#   Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
#
#                              Location    Survey date Weather         Time  \
# 0  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0600 - 0615
# 1  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0615 - 0630
# 2  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0630 - 0645
# 3  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0645 - 0700
# 4  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0700 - 0715
#
#                         Period   Direction  Start hour  Start minute  \
# 0  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 2  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 3  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 4        AM peak (07:00-10:00)  Northbound         7.0           0.0
#
#    Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 0                       0.0                         0.0           0.0
# 1                      15.0                         0.0          15.0
# 2                      35.0                         0.0          35.0
# 3                      59.0                         2.0          61.0
# 4                      73.0                         0.0          73.0
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN

# %%
# Inner London Dataset
# Loading scg into a dataframe

inn_lon = pd.read_csv("Inner London.csv")

# Displaying first 5 Rows of the dataset
inn_lon.head()
# Out:
#    Survey wave (year)   Site ID    Location    Survey date Weather  \
# 0              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 1              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 2              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 3              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 4              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
#
#           Time                       Period   Direction  Start hour  \
# 0  0600 - 0615  Early Morning (06:00-07:00)  Northbound         6.0
# 1  0615 - 0630  Early Morning (06:00-07:00)  Northbound         6.0
# 2  0630 - 0645  Early Morning (06:00-07:00)  Northbound         6.0
# 3  0645 - 0700  Early Morning (06:00-07:00)  Northbound         6.0
# 4  0700 - 0715        AM peak (07:00-10:00)  Northbound         7.0
#
#    Start minute  Number of private cycles  Number of cycle hire bikes  \
# 0           0.0                       1.0                         0.0
# 1          15.0                       2.0                         0.0
# 2          30.0                       2.0                         0.0
# 3          45.0                       4.0                         0.0
# 4           0.0                       4.0                         0.0
#
#    Total cycles
# 0           1.0
# 1           2.0
# 2           2.0
# 3           4.0
# 4           4.0

# %%
# Printing shape of central london dataset
print(cent_lon.shape)
# Out:
# (1048366, 17)

# %%
# Printing shape of Inner london dataset
print(inn_lon.shape)
# Out:
# (615168, 13)

# %%
# Concise summary of Central London Dataset
cent_lon.info
# Out:
# <bound method DataFrame.info of         Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0              2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1              2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2              2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3              2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4              2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# ...                                ...                          ...       ...
# 1048361                            NaN                          NaN       NaN
# 1048362                            NaN                          NaN       NaN
# 1048363                            NaN                          NaN       NaN
# 1048364                            NaN                          NaN       NaN
# 1048365                            NaN                          NaN       NaN
#
#                                    Location    Survey date Weather  \
# 0        Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 1        Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 2        Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 3        Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 4        Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# ...                                     ...            ...     ...
# 1048361                                 NaN            NaN     NaN
# 1048362                                 NaN            NaN     NaN
# 1048363                                 NaN            NaN     NaN
# 1048364                                 NaN            NaN     NaN
# 1048365                                 NaN            NaN     NaN
#
#                 Time                       Period   Direction  Start hour  \
# 0        0600 - 0615  Early Morning (06:00-07:00)  Northbound         6.0
# 1        0615 - 0630  Early Morning (06:00-07:00)  Northbound         6.0
# 2        0630 - 0645  Early Morning (06:00-07:00)  Northbound         6.0
# 3        0645 - 0700  Early Morning (06:00-07:00)  Northbound         6.0
# 4        0700 - 0715        AM peak (07:00-10:00)  Northbound         7.0
# ...              ...                          ...         ...         ...
# 1048361          NaN                          NaN         NaN         NaN
# 1048362          NaN                          NaN         NaN         NaN
# 1048363          NaN                          NaN         NaN         NaN
# 1048364          NaN                          NaN         NaN         NaN
# 1048365          NaN                          NaN         NaN         NaN
#
#          Start minute  Number of private cycles  Number of cycle hire bikes  \
# 0                 0.0                       0.0                         0.0
# 1                15.0                      15.0                         0.0
# 2                30.0                      35.0                         0.0
# 3                45.0                      59.0                         2.0
# 4                 0.0                      73.0                         0.0
# ...               ...                       ...                         ...
# 1048361           NaN                       NaN                         NaN
# 1048362           NaN                       NaN                         NaN
# 1048363           NaN                       NaN                         NaN
# 1048364           NaN                       NaN                         NaN
# 1048365           NaN                       NaN                         NaN
#
#          Total cycles  Unnamed: 14  Unnamed: 15  Unnamed: 16
# 0                 0.0          NaN          NaN          NaN
# 1                15.0          NaN          NaN          NaN
# 2                35.0          NaN          NaN          NaN
# 3                61.0          NaN          NaN          NaN
# 4                73.0          NaN          NaN          NaN
# ...               ...          ...          ...          ...
# 1048361           NaN          NaN          NaN          NaN
# 1048362           NaN          NaN          NaN          NaN
# 1048363           NaN          NaN          NaN          NaN
# 1048364           NaN          NaN          NaN          NaN
# 1048365           NaN          NaN          NaN          NaN
#
# [1048366 rows x 17 columns]>

# %%
cent_lon.dtypes
# Out:
# Survey wave (calendar quarter)     object
# Equivalent financial quarter       object
# Site ID                            object
# Location                           object
# Survey date                        object
# Weather                            object
# Time                               object
# Period                             object
# Direction                          object
# Start hour                        float64
# Start minute                      float64
# Number of private cycles          float64
# Number of cycle hire bikes        float64
# Total cycles                      float64
# Unnamed: 14                       float64
# Unnamed: 15                       float64
# Unnamed: 16                       float64
# dtype: object

# %%
inn_lon.dtypes
# Out:
# Survey wave (year)            float64
# Site ID                        object
# Location                       object
# Survey date                    object
# Weather                        object
# Time                           object
# Period                         object
# Direction                      object
# Start hour                    float64
# Start minute                  float64
# Number of private cycles      float64
# Number of cycle hire bikes    float64
# Total cycles                  float64
# dtype: object

# %%
# identifying the missing values of Central London
cent_lon.isnull()
# Out:
#          Survey wave (calendar quarter)  Equivalent financial quarter  \
# 0                                 False                         False
# 1                                 False                         False
# 2                                 False                         False
# 3                                 False                         False
# 4                                 False                         False
# ...                                 ...                           ...
# 1048361                            True                          True
# 1048362                            True                          True
# 1048363                            True                          True
# 1048364                            True                          True
# 1048365                            True                          True
#
#          Site ID  Location  Survey date  Weather   Time  Period  Direction  \
# 0          False     False        False    False  False   False      False
# 1          False     False        False    False  False   False      False
# 2          False     False        False    False  False   False      False
# 3          False     False        False    False  False   False      False
# 4          False     False        False    False  False   False      False
# ...          ...       ...          ...      ...    ...     ...        ...
# 1048361     True      True         True     True   True    True       True
# 1048362     True      True         True     True   True    True       True
# 1048363     True      True         True     True   True    True       True
# 1048364     True      True         True     True   True    True       True
# 1048365     True      True         True     True   True    True       True
#
#          Start hour  Start minute  Number of private cycles  \
# 0             False         False                     False
# 1             False         False                     False
# 2             False         False                     False
# 3             False         False                     False
# 4             False         False                     False
# ...             ...           ...                       ...
# 1048361        True          True                      True
# 1048362        True          True                      True
# 1048363        True          True                      True
# 1048364        True          True                      True
# 1048365        True          True                      True
#
#          Number of cycle hire bikes  Total cycles  Unnamed: 14  Unnamed: 15  \
# 0                             False         False         True         True
# 1                             False         False         True         True
# 2                             False         False         True         True
# 3                             False         False         True         True
# 4                             False         False         True         True
# ...                             ...           ...          ...          ...
# 1048361                        True          True         True         True
# 1048362                        True          True         True         True
# 1048363                        True          True         True         True
# 1048364                        True          True         True         True
# 1048365                        True          True         True         True
#
#          Unnamed: 16
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# ...              ...
# 1048361         True
# 1048362         True
# 1048363         True
# 1048364         True
# 1048365         True
#
# [1048366 rows x 17 columns]

# %%
# Finding number of missing values in Central London
cent_lon.isnull().sum()
# Out:
# Survey wave (calendar quarter)     290203
# Equivalent financial quarter       290203
# Site ID                            290203
# Location                           290203
# Survey date                        300359
# Weather                            302037
# Time                               290203
# Period                             290203
# Direction                          290203
# Start hour                         290203
# Start minute                       290203
# Number of private cycles           290267
# Number of cycle hire bikes         290267
# Total cycles                       290203
# Unnamed: 14                       1048366
# Unnamed: 15                       1048366
# Unnamed: 16                       1048366
# dtype: int64

# %%
# identifying the missing values of Inner London
inn_lon.isnull()
# Out:
#         Survey wave (year)  Site ID  Location  Survey date  Weather   Time  \
# 0                    False    False     False        False    False  False
# 1                    False    False     False        False    False  False
# 2                    False    False     False        False    False  False
# 3                    False    False     False        False    False  False
# 4                    False    False     False        False    False  False
# ...                    ...      ...       ...          ...      ...    ...
# 615163                True     True      True         True     True   True
# 615164                True     True      True         True     True   True
# 615165                True     True      True         True     True   True
# 615166                True     True      True         True     True   True
# 615167                True     True      True         True     True   True
#
#         Period  Direction  Start hour  Start minute  Number of private cycles  \
# 0        False      False       False         False                     False
# 1        False      False       False         False                     False
# 2        False      False       False         False                     False
# 3        False      False       False         False                     False
# 4        False      False       False         False                     False
# ...        ...        ...         ...           ...                       ...
# 615163    True       True        True          True                      True
# 615164    True       True        True          True                      True
# 615165    True       True        True          True                      True
# 615166    True       True        True          True                      True
# 615167    True       True        True          True                      True
#
#         Number of cycle hire bikes  Total cycles
# 0                            False         False
# 1                            False         False
# 2                            False         False
# 3                            False         False
# 4                            False         False
# ...                            ...           ...
# 615163                        True          True
# 615164                        True          True
# 615165                        True          True
# 615166                        True          True
# 615167                        True          True
#
# [615168 rows x 13 columns]

# %%
# Finding number of missing values in Inner London
inn_lon.isnull().sum()
# Out:
# Survey wave (year)            91392
# Site ID                       91392
# Location                      91392
# Survey date                   94144
# Weather                       96066
# Time                          91398
# Period                        91398
# Direction                     91392
# Start hour                    91398
# Start minute                  91398
# Number of private cycles      91392
# Number of cycle hire bikes    91392
# Total cycles                  91392
# dtype: int64

# %%
# Descriptive statistics of Central London
cent_lon.describe()
# Out:
#           Start hour   Start minute  Number of private cycles  \
# count  758163.000000  758163.000000             758099.000000
# mean       13.499259      22.499951                 14.824374
# std         4.609643      16.770530                 26.255858
# min         6.000000       0.000000                  0.000000
# 25%         9.000000       0.000000                  2.000000
# 50%        13.000000      15.000000                  7.000000
# 75%        17.000000      30.000000                 16.000000
# max        21.000000      45.000000               1177.000000
#
#        Number of cycle hire bikes   Total cycles  Unnamed: 14  Unnamed: 15  \
# count               758099.000000  758163.000000          0.0          0.0
# mean                     1.830072      16.653040          NaN          NaN
# std                      3.321560      28.675116          NaN          NaN
# min                      0.000000       0.000000          NaN          NaN
# 25%                      0.000000       3.000000          NaN          NaN
# 50%                      1.000000       8.000000          NaN          NaN
# 75%                      2.000000      18.000000          NaN          NaN
# max                    108.000000    1200.000000          NaN          NaN
#
#        Unnamed: 16
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %%
# Descriptive Statistics of Inner London

inn_lon.describe()
# Out:
#        Survey wave (year)     Start hour   Start minute  \
# count       523776.000000  523770.000000  523770.000000
# mean          2017.986070      13.499914      22.499914
# std              2.035381       4.609733      16.770551
# min           2015.000000       6.000000       0.000000
# 25%           2016.000000       9.000000       0.000000
# 50%           2018.000000      13.000000      15.000000
# 75%           2020.000000      17.000000      30.000000
# max           2021.000000      21.000000      45.000000
#
#        Number of private cycles  Number of cycle hire bikes   Total cycles
# count             523776.000000               523776.000000  523776.000000
# mean                   5.929833                    0.267943       6.196408
# std                   10.937833                    0.944529      11.309639
# min                    0.000000                    0.000000       0.000000
# 25%                    1.000000                    0.000000       1.000000
# 50%                    3.000000                    0.000000       3.000000
# 75%                    7.000000                    0.000000       7.000000
# max                  278.000000                   29.000000     280.000000

# %% [markdown]
# #### Exploratory Data Analysis of Biking Sites

# %%
# Biking sites Dataset
# Loading csv into a dataframe
bike_site = pd.read_excel("Biking sites.xlsx")

# Displaying first 5 Rows of the dataset
bike_site.head()
# Out:
#       UnqID ProgID           SurveyDescription    Easting   Northing  \
# 0  CENCY001  CENCY  Central area cycle surveys  530251.49  178742.45
# 1  CENCY002  CENCY  Central area cycle surveys  533362.68  181824.45
# 2  CENCY003  CENCY  Central area cycle surveys  532334.06  180520.37
# 3  CENCY004  CENCY  Central area cycle surveys  532052.50  179677.64
# 4  CENCY005  CENCY  Central area cycle surveys  533031.59  180213.46
#
#                              Location         Borough Functional cycling area
# 0  Millbank (south of Thorney Street)     Westminster                 Central
# 1                         Bishopsgate  City of London                 Central
# 2                    Southwark Bridge       Southwark                 Central
# 3               Southwark Bridge Road       Southwark                 Central
# 4                       Tooley Street       Southwark                 Central

# %%
# Viewing the shape of the dataframe
print(bike_site.shape)
# Out:
# (2023, 8)

# %%
# Viewing data types of the dataframe
bike_site.dtypes
# Out:
# UnqID                       object
# ProgID                      object
# SurveyDescription           object
# Easting                    float64
# Northing                   float64
# Location                    object
# Borough                     object
# Functional cycling area     object
# dtype: object

# %%
# FInding Null values
bike_site.isnull()
# Out:
#       UnqID  ProgID  SurveyDescription  Easting  Northing  Location  Borough  \
# 0     False   False              False    False     False     False    False
# 1     False   False              False    False     False     False    False
# 2     False   False              False    False     False     False    False
# 3     False   False              False    False     False     False    False
# 4     False   False              False    False     False     False    False
# ...     ...     ...                ...      ...       ...       ...      ...
# 2018  False   False              False    False     False     False    False
# 2019  False   False              False    False     False     False    False
# 2020  False   False              False    False     False     False    False
# 2021  False   False              False    False     False     False    False
# 2022  False   False              False    False     False     False    False
#
#       Functional cycling area
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 2018                    False
# 2019                    False
# 2020                    False
# 2021                    False
# 2022                    False
#
# [2023 rows x 8 columns]

# %%
bike_site.isnull().sum()
# Out:
# UnqID                      0
# ProgID                     0
# SurveyDescription          0
# Easting                    0
# Northing                   0
# Location                   0
# Borough                    0
# Functional cycling area    2
# dtype: int64

# %%
bike_site.isnull().describe()
# Out:
#         UnqID ProgID SurveyDescription Easting Northing Location Borough  \
# count    2023   2023              2023    2023     2023     2023    2023
# unique      1      1                 1       1        1        1       1
# top     False  False             False   False    False    False   False
# freq     2023   2023              2023    2023     2023     2023    2023
#
#        Functional cycling area
# count                     2023
# unique                       2
# top                      False
# freq                      2021

# %% [markdown]
# ## Data Cleaning <Inner London, Central London, Biking Sites>

# %% [markdown]
# #### Cleaning Central London Dataset

# %%
# Viewing the DataFrames to initiate cleaning
# Central London

cent_lon.head()
# Out:
#   Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
#
#                              Location    Survey date Weather         Time  \
# 0  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0600 - 0615
# 1  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0615 - 0630
# 2  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0630 - 0645
# 3  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0645 - 0700
# 4  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0700 - 0715
#
#                         Period   Direction  Start hour  Start minute  \
# 0  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 2  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 3  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 4        AM peak (07:00-10:00)  Northbound         7.0           0.0
#
#    Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 0                       0.0                         0.0           0.0
# 1                      15.0                         0.0          15.0
# 2                      35.0                         0.0          35.0
# 3                      59.0                         2.0          61.0
# 4                      73.0                         0.0          73.0
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN

# %% [markdown]
# #### Dropping Columns

# %%
# Dropping unnecessary last 3 columns from Central London
cent_lon.drop(['Unnamed: 14','Unnamed: 15','Unnamed: 16'], axis=1, inplace=True)

# %% [markdown]
# #### Dropping Rows

# %%
# Viewing Rows that contain Null Values
cent_lon[cent_lon['Location'].isnull()] #'Location' column is used randomly here, any column can be used here
# Out:
#         Survey wave (calendar quarter) Equivalent financial quarter Site ID  \
# 758163                             NaN                          NaN     NaN
# 758164                             NaN                          NaN     NaN
# 758165                             NaN                          NaN     NaN
# 758166                             NaN                          NaN     NaN
# 758167                             NaN                          NaN     NaN
# ...                                ...                          ...     ...
# 1048361                            NaN                          NaN     NaN
# 1048362                            NaN                          NaN     NaN
# 1048363                            NaN                          NaN     NaN
# 1048364                            NaN                          NaN     NaN
# 1048365                            NaN                          NaN     NaN
#
#         Location Survey date Weather Time Period Direction  Start hour  \
# 758163       NaN         NaN     NaN  NaN    NaN       NaN         NaN
# 758164       NaN         NaN     NaN  NaN    NaN       NaN         NaN
# 758165       NaN         NaN     NaN  NaN    NaN       NaN         NaN
# 758166       NaN         NaN     NaN  NaN    NaN       NaN         NaN
# 758167       NaN         NaN     NaN  NaN    NaN       NaN         NaN
# ...          ...         ...     ...  ...    ...       ...         ...
# 1048361      NaN         NaN     NaN  NaN    NaN       NaN         NaN
# 1048362      NaN         NaN     NaN  NaN    NaN       NaN         NaN
# 1048363      NaN         NaN     NaN  NaN    NaN       NaN         NaN
# 1048364      NaN         NaN     NaN  NaN    NaN       NaN         NaN
# 1048365      NaN         NaN     NaN  NaN    NaN       NaN         NaN
#
#          Start minute  Number of private cycles  Number of cycle hire bikes  \
# 758163            NaN                       NaN                         NaN
# 758164            NaN                       NaN                         NaN
# 758165            NaN                       NaN                         NaN
# 758166            NaN                       NaN                         NaN
# 758167            NaN                       NaN                         NaN
# ...               ...                       ...                         ...
# 1048361           NaN                       NaN                         NaN
# 1048362           NaN                       NaN                         NaN
# 1048363           NaN                       NaN                         NaN
# 1048364           NaN                       NaN                         NaN
# 1048365           NaN                       NaN                         NaN
#
#          Total cycles
# 758163            NaN
# 758164            NaN
# 758165            NaN
# 758166            NaN
# 758167            NaN
# ...               ...
# 1048361           NaN
# 1048362           NaN
# 1048363           NaN
# 1048364           NaN
# 1048365           NaN
#
# [290203 rows x 14 columns]

# %%
# Dropping Rows with all NUll values
cent_lon.drop(cent_lon.index[758163:1048366], inplace=True)

# %%
# Verifying if any rows with Null values are left
cent_lon[cent_lon['Location'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Survey wave (calendar quarter), Equivalent financial quarter, Site ID, Location, Survey date, Weather, Time, Period, Direction, Start hour, Start minute, Number of private cycles, Number of cycle hire bikes, Total cycles]
# Index: []

# %%
# Replacing Null Values in columns with 0's

# 'Survey date' column
cent_lon["Survey date"].fillna(0, inplace=True)

# 'Weather' column
cent_lon["Weather"].fillna(0, inplace=True)

# 'Number of private cycles'
cent_lon["Number of private cycles"].fillna(0, inplace=True)

# 'Number of cycle hire bikes'
cent_lon["Number of cycle hire bikes"].fillna(0, inplace=True)

# %%
# Viewing Dataframe to see if there are any Null values left
cent_lon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 758163 entries, 0 to 758162
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Survey wave (calendar quarter)  758163 non-null  object
#  1   Equivalent financial quarter    758163 non-null  object
#  2   Site ID                         758163 non-null  object
#  3   Location                        758163 non-null  object
#  4   Survey date                     758163 non-null  object
#  5   Weather                         758163 non-null  object
#  6   Time                            758163 non-null  object
#  7   Period                          758163 non-null  object
#  8   Direction                       758163 non-null  object
#  9   Start hour                      758163 non-null  float64
#  10  Start minute                    758163 non-null  float64
#  11  Number of private cycles        758163 non-null  float64
#  12  Number of cycle hire bikes      758163 non-null  float64
#  13  Total cycles                    758163 non-null  float64
# dtypes: float64(5), object(9)
# memory usage: 86.8+ MB

# %% [markdown]
# #### Renaming Column names

# %%
# Renaming Columns for cent_lon
cent_lon.rename(columns = {"Survey wave (calendar quarter)": "calendar_quarter",
                          "Equivalent financial quarter" : "financial_quarter",
                          "Site ID": "site_id",
                          "Location":"location",
                          "Survey date":"survey_date",
                          "Weather":"weather",
                          "Time":"time",
                          "Period":"period",
                          "Direction":"direction",
                          "Start hour":"start_hour",
                          "Start minute":"start_minute",
                          "Number of private cycles":"cycles_private",
                          "Number of cycle hire bikes":"cycles_hire",
                          "Total cycles":"cycles_total"},
                        inplace=True)

# Viewing the Dataframe
cent_lon.head()
# Out:
#           calendar_quarter financial_quarter   site_id  \
# 0  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 1  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 2  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 3  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 4  2014 Q1 (January-March)        2013-14 Q4  CENCY001
#
#                              location    survey_date weather         time  \
# 0  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0600 - 0615
# 1  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0615 - 0630
# 2  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0630 - 0645
# 3  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0645 - 0700
# 4  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0700 - 0715
#
#                         period   direction  start_hour  start_minute  \
# 0  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 2  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 3  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 4        AM peak (07:00-10:00)  Northbound         7.0           0.0
#
#    cycles_private  cycles_hire  cycles_total
# 0             0.0          0.0           0.0
# 1            15.0          0.0          15.0
# 2            35.0          0.0          35.0
# 3            59.0          2.0          61.0
# 4            73.0          0.0          73.0

# %% [markdown]
# ##### Segregating Survey Date Column

# %%
# Segregating days and date from 'Survey_Date' column

# making a temporary data frame for segregation
temp_df_date = cent_lon["survey_date"].str.split("," , n = 1, expand = True)

# Adding new columns in main dataframe for days and dates of survey

# Day Column
cent_lon["day_survey"] = temp_df_date[0]

# Date Column
cent_lon["date_survey"] = temp_df_date[1]

# %%
# Dropping survey_Date column
cent_lon.drop(['survey_date'], axis=1)
# Out:
#                    calendar_quarter financial_quarter   site_id  \
# 0           2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 1           2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 2           2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 3           2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 4           2014 Q1 (January-March)        2013-14 Q4  CENCY001
# ...                             ...               ...       ...
# 758158  2021 Q4 (October-December)         2021-22 Q3  CENCY702
# 758159  2021 Q4 (October-December)         2021-22 Q3  CENCY702
# 758160  2021 Q4 (October-December)         2021-22 Q3  CENCY702
# 758161  2021 Q4 (October-December)         2021-22 Q3  CENCY702
# 758162  2021 Q4 (October-December)         2021-22 Q3  CENCY702
#
#                                   location weather         time  \
# 0       Millbank (south of Thorney Street)     Dry  0600 - 0615
# 1       Millbank (south of Thorney Street)     Dry  0615 - 0630
# 2       Millbank (south of Thorney Street)     Dry  0630 - 0645
# 3       Millbank (south of Thorney Street)     Dry  0645 - 0700
# 4       Millbank (south of Thorney Street)     Dry  0700 - 0715
# ...                                    ...     ...          ...
# 758158                           Haymarket     Dry  2045 - 2100
# 758159                           Haymarket     Dry  2100 - 2115
# 758160                           Haymarket     Dry  2115 - 2130
# 758161                           Haymarket     Dry  2130 - 2145
# 758162                           Haymarket     Dry  2145 - 2200
#
#                              period   direction  start_hour  start_minute  \
# 0       Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1       Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 2       Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 3       Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 4             AM peak (07:00-10:00)  Northbound         7.0           0.0
# ...                             ...         ...         ...           ...
# 758158        Evening (19:00-22:00)  Southbound        20.0          45.0
# 758159        Evening (19:00-22:00)  Southbound        21.0           0.0
# 758160        Evening (19:00-22:00)  Southbound        21.0          15.0
# 758161        Evening (19:00-22:00)  Southbound        21.0          30.0
# 758162        Evening (19:00-22:00)  Southbound        21.0          45.0
#
#         cycles_private  cycles_hire  cycles_total day_survey date_survey
# 0                  0.0          0.0           0.0        ven    24/01/14
# 1                 15.0          0.0          15.0        ven    24/01/14
# 2                 35.0          0.0          35.0        ven    24/01/14
# 3                 59.0          2.0          61.0        ven    24/01/14
# 4                 73.0          0.0          73.0        ven    24/01/14
# ...                ...          ...           ...        ...         ...
# 758158            22.0          1.0          23.0        mar    21/12/21
# 758159            20.0          0.0          20.0        mar    21/12/21
# 758160            16.0          1.0          17.0        mar    21/12/21
# 758161            10.0          1.0          11.0        mar    21/12/21
# 758162            12.0          2.0          14.0        mar    21/12/21
#
# [758163 rows x 15 columns]

# %% [markdown]
# ##### Segregating Time Column

# %%
# Segregating Start and End time  from 'time' column

# making a temporary data frame for segregation
temp_df_time = cent_lon["time"].str.split("-" , n = 1, expand = True)

# Adding new columns in main dataframe for Start and End time of survey
# start time Column
cent_lon["survey_start_time"] = temp_df_time[0]

# end time Column
cent_lon["survey_end_time"] = temp_df_time[1]

# %%
# Dropping time column
cent_lon.drop(['time'], axis=1)
# Out:
#                    calendar_quarter financial_quarter   site_id  \
# 0           2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 1           2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 2           2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 3           2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 4           2014 Q1 (January-March)        2013-14 Q4  CENCY001
# ...                             ...               ...       ...
# 758158  2021 Q4 (October-December)         2021-22 Q3  CENCY702
# 758159  2021 Q4 (October-December)         2021-22 Q3  CENCY702
# 758160  2021 Q4 (October-December)         2021-22 Q3  CENCY702
# 758161  2021 Q4 (October-December)         2021-22 Q3  CENCY702
# 758162  2021 Q4 (October-December)         2021-22 Q3  CENCY702
#
#                                   location    survey_date weather  \
# 0       Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 1       Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 2       Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 3       Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 4       Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# ...                                    ...            ...     ...
# 758158                           Haymarket  mar, 21/12/21     Dry
# 758159                           Haymarket  mar, 21/12/21     Dry
# 758160                           Haymarket  mar, 21/12/21     Dry
# 758161                           Haymarket  mar, 21/12/21     Dry
# 758162                           Haymarket  mar, 21/12/21     Dry
#
#                              period   direction  start_hour  start_minute  \
# 0       Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1       Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 2       Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 3       Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 4             AM peak (07:00-10:00)  Northbound         7.0           0.0
# ...                             ...         ...         ...           ...
# 758158        Evening (19:00-22:00)  Southbound        20.0          45.0
# 758159        Evening (19:00-22:00)  Southbound        21.0           0.0
# 758160        Evening (19:00-22:00)  Southbound        21.0          15.0
# 758161        Evening (19:00-22:00)  Southbound        21.0          30.0
# 758162        Evening (19:00-22:00)  Southbound        21.0          45.0
#
#         cycles_private  cycles_hire  cycles_total day_survey date_survey  \
# 0                  0.0          0.0           0.0        ven    24/01/14
# 1                 15.0          0.0          15.0        ven    24/01/14
# 2                 35.0          0.0          35.0        ven    24/01/14
# 3                 59.0          2.0          61.0        ven    24/01/14
# 4                 73.0          0.0          73.0        ven    24/01/14
# ...                ...          ...           ...        ...         ...
# 758158            22.0          1.0          23.0        mar    21/12/21
# 758159            20.0          0.0          20.0        mar    21/12/21
# 758160            16.0          1.0          17.0        mar    21/12/21
# 758161            10.0          1.0          11.0        mar    21/12/21
# 758162            12.0          2.0          14.0        mar    21/12/21
#
#        survey_start_time survey_end_time
# 0                  0600             0615
# 1                  0615             0630
# 2                  0630             0645
# 3                  0645             0700
# 4                  0700             0715
# ...                  ...             ...
# 758158             2045             2100
# 758159             2100             2115
# 758160             2115             2130
# 758161             2130             2145
# 758162             2145             2200
#
# [758163 rows x 17 columns]

# %% [markdown]
# ##### Segregating Period Column

# %%
# Segregating 'Part of the day' and 'Part of the day time'  from 'time' column

# making a temporary data frame for segregation
temp_df_period = cent_lon["period"].str.split("(" , n = 1, expand = True)

# Adding new columns in main dataframe for Start and End time of survey
# start time Column
cent_lon["day_part"] = temp_df_period[0]

# end time Column
cent_lon["day_part_timeslot"] = temp_df_period[1]

# %%
cent_lon["day_part_timeslot"].str.replace(")", "", regex=True)
# Out:
# 0         06:00-07:00
# 1         06:00-07:00
# 2         06:00-07:00
# 3         06:00-07:00
# 4         07:00-10:00
#              ...
# 758158    19:00-22:00
# 758159    19:00-22:00
# 758160    19:00-22:00
# 758161    19:00-22:00
# 758162    19:00-22:00
# Name: day_part_timeslot, Length: 758163, dtype: object

# %%
cent_lon.head()
# Out:
#           calendar_quarter financial_quarter   site_id  \
# 0  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 1  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 2  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 3  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 4  2014 Q1 (January-March)        2013-14 Q4  CENCY001
#
#                              location    survey_date weather         time  \
# 0  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0600 - 0615
# 1  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0615 - 0630
# 2  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0630 - 0645
# 3  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0645 - 0700
# 4  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0700 - 0715
#
#                         period   direction  start_hour  start_minute  \
# 0  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 2  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 3  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 4        AM peak (07:00-10:00)  Northbound         7.0           0.0
#
#    cycles_private  cycles_hire  cycles_total day_survey date_survey  \
# 0             0.0          0.0           0.0        ven    24/01/14
# 1            15.0          0.0          15.0        ven    24/01/14
# 2            35.0          0.0          35.0        ven    24/01/14
# 3            59.0          2.0          61.0        ven    24/01/14
# 4            73.0          0.0          73.0        ven    24/01/14
#
#   survey_start_time survey_end_time        day_part day_part_timeslot
# 0             0600             0615  Early Morning       06:00-07:00)
# 1             0615             0630  Early Morning       06:00-07:00)
# 2             0630             0645  Early Morning       06:00-07:00)
# 3             0645             0700  Early Morning       06:00-07:00)
# 4             0700             0715        AM peak       07:00-10:00)

# %%
cent_lon_V2 = cent_lon.drop(['period', 'survey_date', 'time'], axis=1)

# %%
#### Replacing 'day_survey' data from French to English

# Friday
cent_lon_V2.loc[cent_lon_V2['day_survey'] == 'ven', 'day_survey_eng'] = 'Friday'

# Monday
cent_lon_V2.loc[cent_lon_V2['day_survey'] == 'lun', 'day_survey_eng'] = 'Monday'

# Tuesday
cent_lon_V2.loc[cent_lon_V2['day_survey'] == 'mar', 'day_survey_eng'] = 'Tuesday'

# Wednesday
cent_lon_V2.loc[cent_lon_V2['day_survey'] == 'mer', 'day_survey_eng'] = 'Wednesday'

# Thursday
cent_lon_V2.loc[cent_lon_V2['day_survey'] == 'jeu', 'day_survey_eng'] = 'Thursday'

# Saturday
cent_lon_V2.loc[cent_lon_V2['day_survey'] == 'sam', 'day_survey_eng'] = 'Saturday'

# Sunday
cent_lon_V2.loc[cent_lon_V2['day_survey'] == 'dim', 'day_survey_eng'] = 'Sunday'

# %%
cent_lon_V3 = cent_lon_V2.drop(['day_survey'], axis=1)

# %%
# Saving Central London Dataframe to CSV file

cent_lon_V3.to_csv('Central_London_Cleaned_280922_V6.csv', index=False)

# %%
cent_lon_clean = pd.read_csv("Central_London_Cleaned_280922_V6.csv")

# %%
print(cent_lon_clean.dtypes)
# Out:
# calendar_quarter      object
# financial_quarter     object
# site_id               object
# location              object
# weather               object
# period                object
# direction             object
# start_hour           float64
# start_minute         float64
# cycles_private       float64
# cycles_hire          float64
# cycles_total         float64
# date_survey           object
# survey_start_time      int64
# survey_end_time        int64
# day_part              object
# day_part_timeslot     object
# day_survey_eng        object
# dtype: object

# %%
cent_lon_clean.head()
# Out:
#           calendar_quarter financial_quarter   site_id  \
# 0  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 1  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 2  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 3  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 4  2014 Q1 (January-March)        2013-14 Q4  CENCY001
#
#                              location weather                       period  \
# 0  Millbank (south of Thorney Street)     Dry  Early Morning (06:00-07:00)
# 1  Millbank (south of Thorney Street)     Dry  Early Morning (06:00-07:00)
# 2  Millbank (south of Thorney Street)     Dry  Early Morning (06:00-07:00)
# 3  Millbank (south of Thorney Street)     Dry  Early Morning (06:00-07:00)
# 4  Millbank (south of Thorney Street)     Dry        AM peak (07:00-10:00)
#
#     direction  start_hour  start_minute  cycles_private  cycles_hire  \
# 0  Northbound         6.0           0.0             0.0          0.0
# 1  Northbound         6.0          15.0            15.0          0.0
# 2  Northbound         6.0          30.0            35.0          0.0
# 3  Northbound         6.0          45.0            59.0          2.0
# 4  Northbound         7.0           0.0            73.0          0.0
#
#    cycles_total date_survey  survey_start_time  survey_end_time  \
# 0           0.0    24/01/14                600              615
# 1          15.0    24/01/14                615              630
# 2          35.0    24/01/14                630              645
# 3          61.0    24/01/14                645              700
# 4          73.0    24/01/14                700              715
#
#          day_part day_part_timeslot day_survey_eng
# 0  Early Morning       06:00-07:00)         Friday
# 1  Early Morning       06:00-07:00)         Friday
# 2  Early Morning       06:00-07:00)         Friday
# 3  Early Morning       06:00-07:00)         Friday
# 4        AM peak       07:00-10:00)         Friday

# %%
# Importing Datetime module

from datetime import datetime

# converting 'survey date' column from object to date

cent_lon_clean['survey_date'] = pd.to_datetime(cent_lon_clean['date_survey'])

# %%
cent_lon_clean.head()
# Out:
#           calendar_quarter financial_quarter   site_id  \
# 0  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 1  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 2  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 3  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 4  2014 Q1 (January-March)        2013-14 Q4  CENCY001
#
#                              location weather                       period  \
# 0  Millbank (south of Thorney Street)     Dry  Early Morning (06:00-07:00)
# 1  Millbank (south of Thorney Street)     Dry  Early Morning (06:00-07:00)
# 2  Millbank (south of Thorney Street)     Dry  Early Morning (06:00-07:00)
# 3  Millbank (south of Thorney Street)     Dry  Early Morning (06:00-07:00)
# 4  Millbank (south of Thorney Street)     Dry        AM peak (07:00-10:00)
#
#     direction  start_hour  start_minute  cycles_private  cycles_hire  \
# 0  Northbound         6.0           0.0             0.0          0.0
# 1  Northbound         6.0          15.0            15.0          0.0
# 2  Northbound         6.0          30.0            35.0          0.0
# 3  Northbound         6.0          45.0            59.0          2.0
# 4  Northbound         7.0           0.0            73.0          0.0
#
#    cycles_total date_survey  survey_start_time  survey_end_time  \
# 0           0.0    24/01/14                600              615
# 1          15.0    24/01/14                615              630
# 2          35.0    24/01/14                630              645
# 3          61.0    24/01/14                645              700
# 4          73.0    24/01/14                700              715
#
#          day_part day_part_timeslot day_survey_eng survey_date
# 0  Early Morning       06:00-07:00)         Friday  2014-01-24
# 1  Early Morning       06:00-07:00)         Friday  2014-01-24
# 2  Early Morning       06:00-07:00)         Friday  2014-01-24
# 3  Early Morning       06:00-07:00)         Friday  2014-01-24
# 4        AM peak       07:00-10:00)         Friday  2014-01-24

# %%
print(cent_lon_clean.dtypes)
# Out:
# calendar_quarter             object
# financial_quarter            object
# site_id                      object
# location                     object
# weather                      object
# period                       object
# direction                    object
# start_hour                  float64
# start_minute                float64
# cycles_private              float64
# cycles_hire                 float64
# cycles_total                float64
# date_survey                  object
# survey_start_time             int64
# survey_end_time               int64
# day_part                     object
# day_part_timeslot            object
# day_survey_eng               object
# survey_date          datetime64[ns]
# dtype: object

# %%
# Converting 'survey_start_time' to time format

pd.to_datetime(cent_lon_clean['survey_start_time'])
# Out:
# 0        1970-01-01 00:00:00.000000600
# 1        1970-01-01 00:00:00.000000615
# 2        1970-01-01 00:00:00.000000630
# 3        1970-01-01 00:00:00.000000645
# 4        1970-01-01 00:00:00.000000700
#                       ...
# 758158   1970-01-01 00:00:00.000002045
# 758159   1970-01-01 00:00:00.000002100
# 758160   1970-01-01 00:00:00.000002115
# 758161   1970-01-01 00:00:00.000002130
# 758162   1970-01-01 00:00:00.000002145
# Name: survey_start_time, Length: 758163, dtype: datetime64[ns]

# %%
cent_lon_clean
# Out:
#                    calendar_quarter financial_quarter   site_id  \
# 0           2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 1           2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 2           2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 3           2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 4           2014 Q1 (January-March)        2013-14 Q4  CENCY001
# ...                             ...               ...       ...
# 758158  2021 Q4 (October-December)         2021-22 Q3  CENCY702
# 758159  2021 Q4 (October-December)         2021-22 Q3  CENCY702
# 758160  2021 Q4 (October-December)         2021-22 Q3  CENCY702
# 758161  2021 Q4 (October-December)         2021-22 Q3  CENCY702
# 758162  2021 Q4 (October-December)         2021-22 Q3  CENCY702
#
#                                   location weather  \
# 0       Millbank (south of Thorney Street)     Dry
# 1       Millbank (south of Thorney Street)     Dry
# 2       Millbank (south of Thorney Street)     Dry
# 3       Millbank (south of Thorney Street)     Dry
# 4       Millbank (south of Thorney Street)     Dry
# ...                                    ...     ...
# 758158                           Haymarket     Dry
# 758159                           Haymarket     Dry
# 758160                           Haymarket     Dry
# 758161                           Haymarket     Dry
# 758162                           Haymarket     Dry
#
#                              period   direction  start_hour  start_minute  \
# 0       Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1       Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 2       Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 3       Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 4             AM peak (07:00-10:00)  Northbound         7.0           0.0
# ...                             ...         ...         ...           ...
# 758158        Evening (19:00-22:00)  Southbound        20.0          45.0
# 758159        Evening (19:00-22:00)  Southbound        21.0           0.0
# 758160        Evening (19:00-22:00)  Southbound        21.0          15.0
# 758161        Evening (19:00-22:00)  Southbound        21.0          30.0
# 758162        Evening (19:00-22:00)  Southbound        21.0          45.0
#
#         cycles_private  cycles_hire  cycles_total date_survey  \
# 0                  0.0          0.0           0.0    24/01/14
# 1                 15.0          0.0          15.0    24/01/14
# 2                 35.0          0.0          35.0    24/01/14
# 3                 59.0          2.0          61.0    24/01/14
# 4                 73.0          0.0          73.0    24/01/14
# ...                ...          ...           ...         ...
# 758158            22.0          1.0          23.0    21/12/21
# 758159            20.0          0.0          20.0    21/12/21
# 758160            16.0          1.0          17.0    21/12/21
# 758161            10.0          1.0          11.0    21/12/21
# 758162            12.0          2.0          14.0    21/12/21
#
#         survey_start_time  survey_end_time        day_part day_part_timeslot  \
# 0                     600              615  Early Morning       06:00-07:00)
# 1                     615              630  Early Morning       06:00-07:00)
# 2                     630              645  Early Morning       06:00-07:00)
# 3                     645              700  Early Morning       06:00-07:00)
# 4                     700              715        AM peak       07:00-10:00)
# ...                   ...              ...             ...               ...
# 758158               2045             2100        Evening       19:00-22:00)
# 758159               2100             2115        Evening       19:00-22:00)
# 758160               2115             2130        Evening       19:00-22:00)
# 758161               2130             2145        Evening       19:00-22:00)
# 758162               2145             2200        Evening       19:00-22:00)
#
#        day_survey_eng survey_date
# 0              Friday  2014-01-24
# 1              Friday  2014-01-24
# 2              Friday  2014-01-24
# 3              Friday  2014-01-24
# 4              Friday  2014-01-24
# ...               ...         ...
# 758158        Tuesday  2021-12-21
# 758159        Tuesday  2021-12-21
# 758160        Tuesday  2021-12-21
# 758161        Tuesday  2021-12-21
# 758162        Tuesday  2021-12-21
#
# [758163 rows x 19 columns]

# %%
print(cent_lon_clean.dtypes)
# Out:
# calendar_quarter             object
# financial_quarter            object
# site_id                      object
# location                     object
# weather                      object
# period                       object
# direction                    object
# start_hour                  float64
# start_minute                float64
# cycles_private              float64
# cycles_hire                 float64
# cycles_total                float64
# date_survey                  object
# survey_start_time             int64
# survey_end_time               int64
# day_part                     object
# day_part_timeslot            object
# day_survey_eng               object
# survey_date          datetime64[ns]
# dtype: object

# %%
cent_lon_clean.head()
# Out:
#           calendar_quarter financial_quarter   site_id  \
# 0  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 1  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 2  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 3  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 4  2014 Q1 (January-March)        2013-14 Q4  CENCY001
#
#                              location weather                       period  \
# 0  Millbank (south of Thorney Street)     Dry  Early Morning (06:00-07:00)
# 1  Millbank (south of Thorney Street)     Dry  Early Morning (06:00-07:00)
# 2  Millbank (south of Thorney Street)     Dry  Early Morning (06:00-07:00)
# 3  Millbank (south of Thorney Street)     Dry  Early Morning (06:00-07:00)
# 4  Millbank (south of Thorney Street)     Dry        AM peak (07:00-10:00)
#
#     direction  start_hour  start_minute  cycles_private  cycles_hire  \
# 0  Northbound         6.0           0.0             0.0          0.0
# 1  Northbound         6.0          15.0            15.0          0.0
# 2  Northbound         6.0          30.0            35.0          0.0
# 3  Northbound         6.0          45.0            59.0          2.0
# 4  Northbound         7.0           0.0            73.0          0.0
#
#    cycles_total date_survey  survey_start_time  survey_end_time  \
# 0           0.0    24/01/14                600              615
# 1          15.0    24/01/14                615              630
# 2          35.0    24/01/14                630              645
# 3          61.0    24/01/14                645              700
# 4          73.0    24/01/14                700              715
#
#          day_part day_part_timeslot day_survey_eng survey_date
# 0  Early Morning       06:00-07:00)         Friday  2014-01-24
# 1  Early Morning       06:00-07:00)         Friday  2014-01-24
# 2  Early Morning       06:00-07:00)         Friday  2014-01-24
# 3  Early Morning       06:00-07:00)         Friday  2014-01-24
# 4        AM peak       07:00-10:00)         Friday  2014-01-24

# %%
# Converting 'survey start and end time' to hours and minutes

cent_lon_clean['survey_start_time'] = pd.to_datetime(cent_lon_clean['survey_start_time'], format='%H%M') 
cent_lon_clean['survey_end_time'] = pd.to_datetime(cent_lon_clean['survey_end_time'], format='%H%M')

# %%
cent_lon_clean.head(100)
# Out:
#            calendar_quarter financial_quarter   site_id  \
# 0   2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 1   2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 2   2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 3   2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 4   2014 Q1 (January-March)        2013-14 Q4  CENCY001
# ..                      ...               ...       ...
# 95  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 96  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 97  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 98  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 99  2014 Q1 (January-March)        2013-14 Q4  CENCY001
#
#                               location weather                       period  \
# 0   Millbank (south of Thorney Street)     Dry  Early Morning (06:00-07:00)
# 1   Millbank (south of Thorney Street)     Dry  Early Morning (06:00-07:00)
# 2   Millbank (south of Thorney Street)     Dry  Early Morning (06:00-07:00)
# 3   Millbank (south of Thorney Street)     Dry  Early Morning (06:00-07:00)
# 4   Millbank (south of Thorney Street)     Dry        AM peak (07:00-10:00)
# ..                                 ...     ...                          ...
# 95  Millbank (south of Thorney Street)     Dry     Inter-peak (10:00-16:00)
# 96  Millbank (south of Thorney Street)     Dry     Inter-peak (10:00-16:00)
# 97  Millbank (south of Thorney Street)     Dry     Inter-peak (10:00-16:00)
# 98  Millbank (south of Thorney Street)     Dry     Inter-peak (10:00-16:00)
# 99  Millbank (south of Thorney Street)     Dry     Inter-peak (10:00-16:00)
#
#      direction  start_hour  start_minute  cycles_private  cycles_hire  \
# 0   Northbound         6.0           0.0             0.0          0.0
# 1   Northbound         6.0          15.0            15.0          0.0
# 2   Northbound         6.0          30.0            35.0          0.0
# 3   Northbound         6.0          45.0            59.0          2.0
# 4   Northbound         7.0           0.0            73.0          0.0
# ..         ...         ...           ...             ...          ...
# 95  Southbound        13.0          45.0             3.0          1.0
# 96  Southbound        14.0           0.0             8.0          2.0
# 97  Southbound        14.0          15.0             8.0          1.0
# 98  Southbound        14.0          30.0             5.0          1.0
# 99  Southbound        14.0          45.0             7.0          0.0
#
#     cycles_total date_survey   survey_start_time     survey_end_time  \
# 0            0.0    24/01/14 1900-01-01 06:00:00 1900-01-01 06:15:00
# 1           15.0    24/01/14 1900-01-01 06:15:00 1900-01-01 06:30:00
# 2           35.0    24/01/14 1900-01-01 06:30:00 1900-01-01 06:45:00
# 3           61.0    24/01/14 1900-01-01 06:45:00 1900-01-01 07:00:00
# 4           73.0    24/01/14 1900-01-01 07:00:00 1900-01-01 07:15:00
# ..           ...         ...                 ...                 ...
# 95           4.0    24/01/14 1900-01-01 13:45:00 1900-01-01 14:00:00
# 96          10.0    22/01/14 1900-01-01 14:00:00 1900-01-01 14:15:00
# 97           9.0    22/01/14 1900-01-01 14:15:00 1900-01-01 14:30:00
# 98           6.0    22/01/14 1900-01-01 14:30:00 1900-01-01 14:45:00
# 99           7.0    22/01/14 1900-01-01 14:45:00 1900-01-01 15:00:00
#
#           day_part day_part_timeslot day_survey_eng survey_date
# 0   Early Morning       06:00-07:00)         Friday  2014-01-24
# 1   Early Morning       06:00-07:00)         Friday  2014-01-24
# 2   Early Morning       06:00-07:00)         Friday  2014-01-24
# 3   Early Morning       06:00-07:00)         Friday  2014-01-24
# 4         AM peak       07:00-10:00)         Friday  2014-01-24
# ..             ...               ...            ...         ...
# 95     Inter-peak       10:00-16:00)         Friday  2014-01-24
# 96     Inter-peak       10:00-16:00)      Wednesday  2014-01-22
# 97     Inter-peak       10:00-16:00)      Wednesday  2014-01-22
# 98     Inter-peak       10:00-16:00)      Wednesday  2014-01-22
# 99     Inter-peak       10:00-16:00)      Wednesday  2014-01-22
#
# [100 rows x 19 columns]

# %%
cent_lon_clean.to_csv('Central_London_Cleaned_280922_V9.csv', index=False)

# %%
cent_lon_clean = pd.read_csv("Central_London_Cleaned_280922_V9.csv")

# %%
cent_lon_clean.head(15)
# Out:
#            calendar_quarter financial_quarter   site_id  \
# 0   2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 1   2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 2   2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 3   2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 4   2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 5   2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 6   2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 7   2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 8   2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 9   2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 10  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 11  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 12  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 13  2014 Q1 (January-March)        2013-14 Q4  CENCY001
# 14  2014 Q1 (January-March)        2013-14 Q4  CENCY001
#
#                               location weather                       period  \
# 0   Millbank (south of Thorney Street)     Dry  Early Morning (06:00-07:00)
# 1   Millbank (south of Thorney Street)     Dry  Early Morning (06:00-07:00)
# 2   Millbank (south of Thorney Street)     Dry  Early Morning (06:00-07:00)
# 3   Millbank (south of Thorney Street)     Dry  Early Morning (06:00-07:00)
# 4   Millbank (south of Thorney Street)     Dry        AM peak (07:00-10:00)
# 5   Millbank (south of Thorney Street)     Dry        AM peak (07:00-10:00)
# 6   Millbank (south of Thorney Street)     Dry        AM peak (07:00-10:00)
# 7   Millbank (south of Thorney Street)     Dry        AM peak (07:00-10:00)
# 8   Millbank (south of Thorney Street)     Dry        AM peak (07:00-10:00)
# 9   Millbank (south of Thorney Street)     Dry        AM peak (07:00-10:00)
# 10  Millbank (south of Thorney Street)     Dry        AM peak (07:00-10:00)
# 11  Millbank (south of Thorney Street)     Dry        AM peak (07:00-10:00)
# 12  Millbank (south of Thorney Street)     Dry        AM peak (07:00-10:00)
# 13  Millbank (south of Thorney Street)     Dry        AM peak (07:00-10:00)
# 14  Millbank (south of Thorney Street)     Dry        AM peak (07:00-10:00)
#
#      direction  start_hour  start_minute  cycles_private  cycles_hire  \
# 0   Northbound         6.0           0.0             0.0          0.0
# 1   Northbound         6.0          15.0            15.0          0.0
# 2   Northbound         6.0          30.0            35.0          0.0
# 3   Northbound         6.0          45.0            59.0          2.0
# 4   Northbound         7.0           0.0            73.0          0.0
# 5   Northbound         7.0          15.0            89.0          2.0
# 6   Northbound         7.0          30.0           151.0          3.0
# 7   Northbound         7.0          45.0           173.0          2.0
# 8   Northbound         8.0           0.0           274.0          1.0
# 9   Northbound         8.0          15.0           248.0          4.0
# 10  Northbound         8.0          30.0           255.0          2.0
# 11  Northbound         8.0          45.0           259.0          6.0
# 12  Northbound         9.0           0.0           128.0          0.0
# 13  Northbound         9.0          15.0            85.0          4.0
# 14  Northbound         9.0          30.0            77.0          2.0
#
#     cycles_total date_survey    survey_start_time      survey_end_time  \
# 0            0.0    24/01/14  1900-01-01 06:00:00  1900-01-01 06:15:00
# 1           15.0    24/01/14  1900-01-01 06:15:00  1900-01-01 06:30:00
# 2           35.0    24/01/14  1900-01-01 06:30:00  1900-01-01 06:45:00
# 3           61.0    24/01/14  1900-01-01 06:45:00  1900-01-01 07:00:00
# 4           73.0    24/01/14  1900-01-01 07:00:00  1900-01-01 07:15:00
# 5           91.0    24/01/14  1900-01-01 07:15:00  1900-01-01 07:30:00
# 6          154.0    24/01/14  1900-01-01 07:30:00  1900-01-01 07:45:00
# 7          175.0    24/01/14  1900-01-01 07:45:00  1900-01-01 08:00:00
# 8          275.0    24/01/14  1900-01-01 08:00:00  1900-01-01 08:15:00
# 9          252.0    24/01/14  1900-01-01 08:15:00  1900-01-01 08:30:00
# 10         257.0    24/01/14  1900-01-01 08:30:00  1900-01-01 08:45:00
# 11         265.0    24/01/14  1900-01-01 08:45:00  1900-01-01 09:00:00
# 12         128.0    24/01/14  1900-01-01 09:00:00  1900-01-01 09:15:00
# 13          89.0    24/01/14  1900-01-01 09:15:00  1900-01-01 09:30:00
# 14          79.0    24/01/14  1900-01-01 09:30:00  1900-01-01 09:45:00
#
#           day_part day_part_timeslot day_survey_eng survey_date
# 0   Early Morning       06:00-07:00)         Friday  2014-01-24
# 1   Early Morning       06:00-07:00)         Friday  2014-01-24
# 2   Early Morning       06:00-07:00)         Friday  2014-01-24
# 3   Early Morning       06:00-07:00)         Friday  2014-01-24
# 4         AM peak       07:00-10:00)         Friday  2014-01-24
# 5         AM peak       07:00-10:00)         Friday  2014-01-24
# 6         AM peak       07:00-10:00)         Friday  2014-01-24
# 7         AM peak       07:00-10:00)         Friday  2014-01-24
# 8         AM peak       07:00-10:00)         Friday  2014-01-24
# 9         AM peak       07:00-10:00)         Friday  2014-01-24
# 10        AM peak       07:00-10:00)         Friday  2014-01-24
# 11        AM peak       07:00-10:00)         Friday  2014-01-24
# 12        AM peak       07:00-10:00)         Friday  2014-01-24
# 13        AM peak       07:00-10:00)         Friday  2014-01-24
# 14        AM peak       07:00-10:00)         Friday  2014-01-24

# %% [markdown]
# #### Cleaning Inner London Dataset

# %%
inn_lon.head()
# Out:
#    Survey wave (year)   Site ID    Location    Survey date Weather  \
# 0              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 1              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 2              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 3              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 4              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
#
#           Time                       Period   Direction  Start hour  \
# 0  0600 - 0615  Early Morning (06:00-07:00)  Northbound         6.0
# 1  0615 - 0630  Early Morning (06:00-07:00)  Northbound         6.0
# 2  0630 - 0645  Early Morning (06:00-07:00)  Northbound         6.0
# 3  0645 - 0700  Early Morning (06:00-07:00)  Northbound         6.0
# 4  0700 - 0715        AM peak (07:00-10:00)  Northbound         7.0
#
#    Start minute  Number of private cycles  Number of cycle hire bikes  \
# 0           0.0                       1.0                         0.0
# 1          15.0                       2.0                         0.0
# 2          30.0                       2.0                         0.0
# 3          45.0                       4.0                         0.0
# 4           0.0                       4.0                         0.0
#
#    Total cycles
# 0           1.0
# 1           2.0
# 2           2.0
# 3           4.0
# 4           4.0

# %%
print(inn_lon.dtypes)
# Out:
# Survey wave (year)            float64
# Site ID                        object
# Location                       object
# Survey date                    object
# Weather                        object
# Time                           object
# Period                         object
# Direction                      object
# Start hour                    float64
# Start minute                  float64
# Number of private cycles      float64
# Number of cycle hire bikes    float64
# Total cycles                  float64
# dtype: object

# %%
# Printing shape of Inner london dataset
print(inn_lon.shape)
# Out:
# (615168, 13)

# %%
# Viewing 'NULL' values
inn_lon.isnull()
# Out:
#         Survey wave (year)  Site ID  Location  Survey date  Weather   Time  \
# 0                    False    False     False        False    False  False
# 1                    False    False     False        False    False  False
# 2                    False    False     False        False    False  False
# 3                    False    False     False        False    False  False
# 4                    False    False     False        False    False  False
# ...                    ...      ...       ...          ...      ...    ...
# 615163                True     True      True         True     True   True
# 615164                True     True      True         True     True   True
# 615165                True     True      True         True     True   True
# 615166                True     True      True         True     True   True
# 615167                True     True      True         True     True   True
#
#         Period  Direction  Start hour  Start minute  Number of private cycles  \
# 0        False      False       False         False                     False
# 1        False      False       False         False                     False
# 2        False      False       False         False                     False
# 3        False      False       False         False                     False
# 4        False      False       False         False                     False
# ...        ...        ...         ...           ...                       ...
# 615163    True       True        True          True                      True
# 615164    True       True        True          True                      True
# 615165    True       True        True          True                      True
# 615166    True       True        True          True                      True
# 615167    True       True        True          True                      True
#
#         Number of cycle hire bikes  Total cycles
# 0                            False         False
# 1                            False         False
# 2                            False         False
# 3                            False         False
# 4                            False         False
# ...                            ...           ...
# 615163                        True          True
# 615164                        True          True
# 615165                        True          True
# 615166                        True          True
# 615167                        True          True
#
# [615168 rows x 13 columns]

# %%
inn_lon.isnull().sum()
# Out:
# Survey wave (year)            91392
# Site ID                       91392
# Location                      91392
# Survey date                   94144
# Weather                       96066
# Time                          91398
# Period                        91398
# Direction                     91392
# Start hour                    91398
# Start minute                  91398
# Number of private cycles      91392
# Number of cycle hire bikes    91392
# Total cycles                  91392
# dtype: int64

# %%
# Viewing Rows that contain Null Values
inn_lon[inn_lon['Location'].isnull()] #'Location' column is used randomly here, any column can be used here
# Out:
#         Survey wave (year) Site ID Location Survey date Weather Time Period  \
# 523776                 NaN     NaN      NaN         NaN     NaN  NaN    NaN
# 523777                 NaN     NaN      NaN         NaN     NaN  NaN    NaN
# 523778                 NaN     NaN      NaN         NaN     NaN  NaN    NaN
# 523779                 NaN     NaN      NaN         NaN     NaN  NaN    NaN
# 523780                 NaN     NaN      NaN         NaN     NaN  NaN    NaN
# ...                    ...     ...      ...         ...     ...  ...    ...
# 615163                 NaN     NaN      NaN         NaN     NaN  NaN    NaN
# 615164                 NaN     NaN      NaN         NaN     NaN  NaN    NaN
# 615165                 NaN     NaN      NaN         NaN     NaN  NaN    NaN
# 615166                 NaN     NaN      NaN         NaN     NaN  NaN    NaN
# 615167                 NaN     NaN      NaN         NaN     NaN  NaN    NaN
#
#        Direction  Start hour  Start minute  Number of private cycles  \
# 523776       NaN         NaN           NaN                       NaN
# 523777       NaN         NaN           NaN                       NaN
# 523778       NaN         NaN           NaN                       NaN
# 523779       NaN         NaN           NaN                       NaN
# 523780       NaN         NaN           NaN                       NaN
# ...          ...         ...           ...                       ...
# 615163       NaN         NaN           NaN                       NaN
# 615164       NaN         NaN           NaN                       NaN
# 615165       NaN         NaN           NaN                       NaN
# 615166       NaN         NaN           NaN                       NaN
# 615167       NaN         NaN           NaN                       NaN
#
#         Number of cycle hire bikes  Total cycles
# 523776                         NaN           NaN
# 523777                         NaN           NaN
# 523778                         NaN           NaN
# 523779                         NaN           NaN
# 523780                         NaN           NaN
# ...                            ...           ...
# 615163                         NaN           NaN
# 615164                         NaN           NaN
# 615165                         NaN           NaN
# 615166                         NaN           NaN
# 615167                         NaN           NaN
#
# [91392 rows x 13 columns]

# %%
# Dropping Rows with all NUll values
inn_lon.drop(inn_lon.index[523776:615168], inplace=True)

# %%
inn_lon.isnull().sum()
# Out:
# calendar_year        0
# site_id              0
# location             0
# survey_date       2752
# weather           4674
# time                 6
# period               6
# direction            0
# start_hour           6
# start_minute         6
# cycles_private       0
# cycles_hire          0
# cycles_total         0
# day_survey        2752
# date_survey       2752
# dtype: int64

# %%
# Viewing Dataframe to see if there are any Null values left
inn_lon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 523776 entries, 0 to 523775
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Survey wave (year)          523776 non-null  float64
#  1   Site ID                     523776 non-null  object
#  2   Location                    523776 non-null  object
#  3   Survey date                 521024 non-null  object
#  4   Weather                     519102 non-null  object
#  5   Time                        523770 non-null  object
#  6   Period                      523770 non-null  object
#  7   Direction                   523776 non-null  object
#  8   Start hour                  523770 non-null  float64
#  9   Start minute                523770 non-null  float64
#  10  Number of private cycles    523776 non-null  float64
#  11  Number of cycle hire bikes  523776 non-null  float64
#  12  Total cycles                523776 non-null  float64
# dtypes: float64(6), object(7)
# memory usage: 55.9+ MB

# %% [markdown]
# #### Renaming Column names

# %%
# Renaming Columns for inn_lon
inn_lon.rename(columns = {"Survey wave (year)": "calendar_quarter",
                          "Site ID": "site_id",
                          "Location":"location",
                          "Survey date":"survey_date",
                          "Weather":"weather",
                          "Time":"time",
                          "Period":"period",
                          "Direction":"direction",
                          "Start hour":"start_hour",
                          "Start minute":"start_minute",
                          "Number of private cycles":"cycles_private",
                          "Number of cycle hire bikes":"cycles_hire",
                          "Total cycles":"cycles_total"},
                        inplace=True)

# Viewing the Dataframe
inn_lon.head()
# Out:
#    calendar_quarter   site_id    location    survey_date weather         time  \
# 0            2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry  0600 - 0615
# 1            2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry  0615 - 0630
# 2            2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry  0630 - 0645
# 3            2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry  0645 - 0700
# 4            2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry  0700 - 0715
#
#                         period   direction  start_hour  start_minute  \
# 0  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 2  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 3  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 4        AM peak (07:00-10:00)  Northbound         7.0           0.0
#
#    cycles_private  cycles_hire  cycles_total
# 0             1.0          0.0           1.0
# 1             2.0          0.0           2.0
# 2             2.0          0.0           2.0
# 3             4.0          0.0           4.0
# 4             4.0          0.0           4.0

# %% [markdown]
# #### Segregating Survey Date Column

# %%
# Segregating days and date from 'Survey_Date' column

# making a temporary data frame for segregation
temp_df_date_1 = inn_lon["survey_date"].str.split("," , n = 1, expand = True)

# Adding new columns in main dataframe for days and dates of survey

# Day Column
inn_lon["day_survey"] = temp_df_date_1[0]

# Date Column
inn_lon["date_survey"] = temp_df_date_1[1]

# %%
inn_lon.rename(columns = {"calendar_quarter": "calendar_year"}, inplace=True)

# %%
inn_lon.head()
# Out:
#    calendar_year   site_id    location    survey_date weather         time  \
# 0         2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry  0600 - 0615
# 1         2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry  0615 - 0630
# 2         2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry  0630 - 0645
# 3         2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry  0645 - 0700
# 4         2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry  0700 - 0715
#
#                         period   direction  start_hour  start_minute  \
# 0  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 2  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 3  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 4        AM peak (07:00-10:00)  Northbound         7.0           0.0
#
#    cycles_private  cycles_hire  cycles_total day_survey date_survey
# 0             1.0          0.0           1.0        mer    20/05/15
# 1             2.0          0.0           2.0        mer    20/05/15
# 2             2.0          0.0           2.0        mer    20/05/15
# 3             4.0          0.0           4.0        mer    20/05/15
# 4             4.0          0.0           4.0        mer    20/05/15

# %%
inn_lon.tail()
# Out:
#         calendar_year   site_id       location    survey_date weather  \
# 523771         2021.0  INNCY597  Augustus Road  mer, 26/05/21     Dry
# 523772         2021.0  INNCY597  Augustus Road  mer, 26/05/21     Dry
# 523773         2021.0  INNCY597  Augustus Road  mer, 26/05/21     Dry
# 523774         2021.0  INNCY597  Augustus Road  mer, 26/05/21     Dry
# 523775         2021.0  INNCY597  Augustus Road  mer, 26/05/21     Dry
#
#                time                 period  direction  start_hour  \
# 523771  2045 - 2100  Evening (19:00-22:00)  Westbound        20.0
# 523772  2100 - 2115  Evening (19:00-22:00)  Westbound        21.0
# 523773  2115 - 2130  Evening (19:00-22:00)  Westbound        21.0
# 523774  2130 - 2145  Evening (19:00-22:00)  Westbound        21.0
# 523775  2145 - 2200  Evening (19:00-22:00)  Westbound        21.0
#
#         start_minute  cycles_private  cycles_hire  cycles_total day_survey  \
# 523771          45.0             3.0          0.0           3.0        mer
# 523772           0.0             2.0          0.0           2.0        mer
# 523773          15.0             2.0          0.0           2.0        mer
# 523774          30.0             2.0          0.0           2.0        mer
# 523775          45.0             0.0          0.0           0.0        mer
#
#        date_survey
# 523771    26/05/21
# 523772    26/05/21
# 523773    26/05/21
# 523774    26/05/21
# 523775    26/05/21

# %%
# Replacing Null Values in columns with 0's
# each column has been seperately addresses 
# as entire dataframe command (df.fillna(0)) was not working

# 'Survey date' column
inn_lon["survey_date"].fillna(0, inplace=True)

# 'Weather' column
inn_lon["weather"].fillna(0, inplace=True)

# 'time' column
inn_lon["time"].fillna(0, inplace=True)

# 'period' column
inn_lon["period"].fillna(0, inplace=True)

# 'period' column
inn_lon["period"].fillna(0, inplace=True)

# 'start_hour' column
inn_lon["start_hour"].fillna(0, inplace=True)

# 'day_survey'
inn_lon["start_minute"].fillna(0, inplace=True)

# 'day_survey'
inn_lon["date_survey"].fillna(0, inplace=True)

# %%
# Changing data types of columns from float to int

inn_lon['calendar_year'] = inn_lon['calendar_year'].astype(int)
inn_lon['start_hour'] = inn_lon['start_hour'].astype(int)
inn_lon['start_minute'] = inn_lon['start_minute'].astype(int)
inn_lon['cycles_private'] = inn_lon['cycles_private'].astype(int)
inn_lon['cycles_hire'] = inn_lon['cycles_hire'].astype(int)
inn_lon['cycles_total'] = inn_lon['cycles_total'].astype(int)

# %% [markdown]
# #### Segregating Time Column

# %%
# Segregating Start and End time  from 'time' column

# making a temporary data frame for segregation
temp_df_time_1 = inn_lon["time"].str.split("-" , n = 1, expand = True)

# Adding new columns in main dataframe for Start and End time of survey
# start time Column
inn_lon["survey_start_time"] = temp_df_time_1[0]

# end time Column
inn_lon["survey_end_time"] = temp_df_time_1[1]

# %% [markdown]
# #### Segregating Period Column

# %%
# Segregating 'Part of the day' and 'Part of the day time'  from 'time' column

# making a temporary data frame for segregation
temp_df_period_1 = inn_lon["period"].str.split("(" , n = 1, expand = True)

# Adding new columns in main dataframe for Start and End time of survey
# start time Column
inn_lon["day_part"] = temp_df_period_1[0]

# end time Column
inn_lon["day_part_timeslot"] = temp_df_period_1[1]

# %%
inn_lon["day_part_timeslot"].str.replace(")", "", regex=True)
# Out:
# 0         06:00-07:00
# 1         06:00-07:00
# 2         06:00-07:00
# 3         06:00-07:00
# 4         07:00-10:00
#              ...
# 523771    19:00-22:00
# 523772    19:00-22:00
# 523773    19:00-22:00
# 523774    19:00-22:00
# 523775    19:00-22:00
# Name: day_part_timeslot, Length: 523776, dtype: object

# %%
# Dropping Original combine columns
# Cpying into another dataframe (V2) in case need to revert
inn_lon_V2 = inn_lon.drop(['period', 'survey_date', 'time'], axis=1)

# %%
#### Replacing 'day_survey' data from French to English

# Friday
inn_lon_V2.loc[inn_lon_V2['day_survey'] == 'ven', 'day_survey_eng'] = 'Friday'

# Monday
inn_lon_V2.loc[inn_lon_V2['day_survey'] == 'lun', 'day_survey_eng'] = 'Monday'

# Tuesday
inn_lon_V2.loc[inn_lon_V2['day_survey'] == 'mar', 'day_survey_eng'] = 'Tuesday'

# Wednesday
inn_lon_V2.loc[inn_lon_V2['day_survey'] == 'mer', 'day_survey_eng'] = 'Wednesday'

# Thursday
inn_lon_V2.loc[inn_lon_V2['day_survey'] == 'jeu', 'day_survey_eng'] = 'Thursday'

# Saturday
inn_lon_V2.loc[inn_lon_V2['day_survey'] == 'sam', 'day_survey_eng'] = 'Saturday'

# Sunday
inn_lon_V2.loc[inn_lon_V2['day_survey'] == 'dim', 'day_survey_eng'] = 'Sunday'

# %%
inn_lon_V2.drop(['day_survey'], axis=1, inplace=True)

# %%
inn_lon_V2
# Out:
#         calendar_year   site_id       location weather   direction  \
# 0                2015  INNCY001     Grove Road     Dry  Northbound
# 1                2015  INNCY001     Grove Road     Dry  Northbound
# 2                2015  INNCY001     Grove Road     Dry  Northbound
# 3                2015  INNCY001     Grove Road     Dry  Northbound
# 4                2015  INNCY001     Grove Road     Dry  Northbound
# ...               ...       ...            ...     ...         ...
# 523771           2021  INNCY597  Augustus Road     Dry   Westbound
# 523772           2021  INNCY597  Augustus Road     Dry   Westbound
# 523773           2021  INNCY597  Augustus Road     Dry   Westbound
# 523774           2021  INNCY597  Augustus Road     Dry   Westbound
# 523775           2021  INNCY597  Augustus Road     Dry   Westbound
#
#         start_hour  start_minute  cycles_private  cycles_hire  cycles_total  \
# 0                6             0               1            0             1
# 1                6            15               2            0             2
# 2                6            30               2            0             2
# 3                6            45               4            0             4
# 4                7             0               4            0             4
# ...            ...           ...             ...          ...           ...
# 523771          20            45               3            0             3
# 523772          21             0               2            0             2
# 523773          21            15               2            0             2
# 523774          21            30               2            0             2
# 523775          21            45               0            0             0
#
#        date_survey        day_part day_part_timeslot survey_start_time  \
# 0         20/05/15  Early Morning       06:00-07:00)             0600
# 1         20/05/15  Early Morning       06:00-07:00)             0615
# 2         20/05/15  Early Morning       06:00-07:00)             0630
# 3         20/05/15  Early Morning       06:00-07:00)             0645
# 4         20/05/15        AM peak       07:00-10:00)             0700
# ...            ...             ...               ...               ...
# 523771    26/05/21        Evening       19:00-22:00)             2045
# 523772    26/05/21        Evening       19:00-22:00)             2100
# 523773    26/05/21        Evening       19:00-22:00)             2115
# 523774    26/05/21        Evening       19:00-22:00)             2130
# 523775    26/05/21        Evening       19:00-22:00)             2145
#
#        survey_end_time day_survey_eng
# 0                 0615      Wednesday
# 1                 0630      Wednesday
# 2                 0645      Wednesday
# 3                 0700      Wednesday
# 4                 0715      Wednesday
# ...                ...            ...
# 523771            2100      Wednesday
# 523772            2115      Wednesday
# 523773            2130      Wednesday
# 523774            2145      Wednesday
# 523775            2200      Wednesday
#
# [523776 rows x 16 columns]

# %% [markdown]
# #### Converting data types to DATE TIME format

# %%
# Importing Datetime module

from datetime import datetime

# converting 'survey date' column from object to date

inn_lon_V2['date_survey'] = pd.to_datetime(inn_lon_V2['date_survey'])

# %%
inn_lon_V2.to_csv('Inner_London_Cleaned_031022_V1.csv', index=False)
